# %% [markdown]
# ### Task 5 - Bussiness Analytics

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %%
#load the data
df1 = pd.read_csv('SampleSuperstore.csv')

df1.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %% [markdown]
# ### Processing The Data

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df1.describe(include = 'all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %%
#uniqe value
df1.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df1.Region.value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df1.select_dtypes(include = object).columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category'],
#       dtype='object')

# %%
df1.select_dtypes(include= [np.number]).columns
# Out:
# Index(['Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %% [markdown]
# ### Data Visualization

# %%
sns.countplot(x = 'Ship Mode' , data = df1)

# %%
sns.countplot(x = 'Segment' , data = df1)

# %%
sns.countplot(x = 'Region' , data = df1)

# %%
sns.countplot(x = 'Category' , data = df1)

# %% [markdown]
# ### plotting the data

# %%
plt.figure(1)
plt.subplot(221)
df1['Category'].value_counts().plot.bar(figsize=(20,10), color='lightcoral', title='Category')
plt.subplot(222)
df1['Segment'].value_counts().plot.bar(color='mediumpurple', title='Segment')
plt.subplot(223)
df1['Ship Mode'].value_counts().plot.bar(color='forestgreen', title='Shop Mode')
plt.subplot(224)
df1['Region'].value_counts().plot.bar(color='yellowgreen', title='Region')

plt.show()

# %% [markdown]
# ### It can be inferred from the above count plots that
#
# - Office Supplies Sales are majority in the Category
# - Consumers consist as majority in the segment
# - Majority prefer the Standrd Class as the Mode of Shipping
# - Maximum sales is from the West region

# %%
# Plotting a pairplot among all the variables
sns.pairplot(df1)
plt.show()

# %%
df1.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
corr = df1.corr()

#Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

#matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

#diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

#heatmap
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.catplot(x ="Ship Mode", y="Profit", data = df1, color='limegreen', height=4, aspect=4);

# %%
sns.catplot(x ="Region", y="Profit", data = df1, color ='gold', height=4, aspect=4);

# %%
sns.catplot(x ="Category", y="Profit", data = df1, color ='gold', height=4, aspect=4);

# %%
sns.catplot(x ="Sub-Category", y="Profit", data = df1, color='cyan', height=4, aspect=4);

# %% [markdown]
# ### We infer from the Catplot that:
#
# - The Standard ship Mode is the most profitable one
# - The technology category is the most profitable
#
# - The East Region seems more profitable out of the other regions
# - The Binders from the Sub Category are the most profitable items to be sold
